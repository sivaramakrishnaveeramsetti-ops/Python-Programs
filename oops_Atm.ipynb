# %% [markdown]
# <a href="https://colab.research.google.com/github/sivaramakrishnaveeramsetti-ops/Python-Programs/blob/main/oops_Atm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Atm_machine:
  Bank_name="Yes Bank"

  def __init__(self,name,balance=0.0):
    self.name=name
    self.balance=balance

  def deposit(self,amount):
    self.balance=self.balance+amount
    print("your amount is successfully added..")
    print("current balance :",self.balance)

  def withdrawl(self,amount):
    if amount>self.balance:
     print("your current balance :",self.balance)
    else:
      self.balance-=amount
      print("please collect your balance")
      print("After withdrawl:",self.balance)

  def check_balance(self):
     print("your current balance:",self.balance)

print("Welcome to", Atm_machine.Bank_name)
name=input("enter your name :")
user=Atm_machine(name)

while True:
    print("\n------ ATM MENU ------")
    print("1. Deposit")
    print("2. Withdraw")
    print("3. Check Balance")
    print("4. Exit")

    choice=int(input("enter your choice : "))

    if choice == 1:
      amount=float(input("enter your amount :"))
      user.deposit(amount)
    elif choice == 2:
      amount=float(input("enter your amount :"))
      user.withdrawl(amount)
    elif choice == 3:
      user.check_balance()
    elif choice == 4:
      print("Thank you for using ATM.")
      break
    else:
     print("Invalid option. Try again.")
# Out:
# Welcome to Yes Bank
# enter your name :SivaRamaKrishna
#
# ------ ATM MENU ------
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# enter your choice : 2
# enter your amount :50000
# your current balance : 0.0
#
# ------ ATM MENU ------
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# enter your choice : 1
# enter your amount :60000
# your amount is successfully added..
# current balance : 60000.0
#
# ------ ATM MENU ------
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# enter your choice : 3
# your current balance: 60000.0
#
# ------ ATM MENU ------
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# enter your choice : 4
# Thank you for using ATM.
